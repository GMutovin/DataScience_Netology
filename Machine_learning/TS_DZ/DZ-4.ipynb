# %% [markdown]
# # Домашнее задание «Модели авторегрессии условной гетероскедантичности»

# %% [markdown]
# Выберите ряд из первого задания и постройте его модель GARCH.

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm
import statsmodels.tsa.api as smt
import matplotlib.pyplot as plt
from scipy.stats import boxcox

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
def test_stationarity(timeseries):
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
    for [key, value] in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)

# %%
def tsplot(y, lags=None, figsize=(14, 8), style='bmh'):
    test_stationarity(y)
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
    with plt.style.context(style):
        plt.figure(figsize=figsize)
        layout = (5, 1)
        ts_ax = plt.subplot2grid(layout, (0, 0), rowspan=2)
        acf_ax = plt.subplot2grid(layout, (2, 0))
        pacf_ax = plt.subplot2grid(layout, (3, 0))
        qq_ax = plt.subplot2grid(layout, (4, 0))

        y.plot(ax=ts_ax, color='blue', label='Or')
        ts_ax.set_title('Original')

        smt.graphics.plot_acf(y, lags=lags, ax=acf_ax, alpha=0.05)
        smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax, alpha=0.05)
        sm.qqplot(y, line='s', ax=qq_ax)
        
        plt.tight_layout()
    return

# %%
series = pd.read_csv("/Users/glebmutovin/Data_Science/DataScience_Netology/Machine_learning/TimeSeries/1._Лекция/Series/monthly-sales-of-company-x-jan-6.csv").dropna().values[:, 1]

# %% [markdown]
# Построим GARCH модель

# %%
pip install arch
# Out:
# Collecting arch
#   Downloading arch-5.3.1-cp38-cp38-macosx_10_9_x86_64.whl (876 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 876.1/876.1 KB 2.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: scipy>=1.3 in /Users/glebmutovin/Downloads/ENTER/lib/python3.8/site-packages (from arch) (1.6.2)
# Collecting property-cached>=1.6.4
#   Downloading property_cached-1.6.4-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: statsmodels>=0.11 in /Users/glebmutovin/Downloads/ENTER/lib/python3.8/site-packages (from arch) (0.12.2)
# Requirement already satisfied: numpy>=1.17 in /Users/glebmutovin/Downloads/ENTER/lib/python3.8/site-packages (from arch) (1.20.1)
# Requirement already satisfied: pandas>=1.0 in /Users/glebmutovin/Downloads/ENTER/lib/python3.8/site-packages (from arch) (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/glebmutovin/Downloads/ENTER/lib/python3.8/site-packages (from pandas>=1.0->arch) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/glebmutovin/Downloads/ENTER/lib/python3.8/site-packages (from pandas>=1.0->arch) (2021.1)
# Requirement already satisfied: patsy>=0.5 in /Users/glebmutovin/Downloads/ENTER/lib/python3.8/site-packages (from statsmodels>=0.11->arch) (0.5.1)
# Requirement already satisfied: six in /Users/glebmutovin/Downloads/ENTER/lib/python3.8/site-packages (from patsy>=0.5->statsmodels>=0.11->arch) (1.15.0)
# Installing collected packages: property-cached, arch
# Successfully installed arch-5.3.1 property-cached-1.6.4
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/Users/glebmutovin/Downloads/ENTER/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from arch import arch_model

# %%
def _get_best_model(TS):
    best_aic = np.inf 
    best_order = None
    best_mdl = None

    for i in range(5):
        for d in range(5):
            for j in range(5):
                try:
                    tmp_mdl = smt.ARIMA(TS, order=(i,d,j)).fit(
                        method='mle', trend='nc'
                    )
                    tmp_aic = tmp_mdl.aic
                    if tmp_aic < best_aic:
                        best_aic = tmp_aic
                        best_order = (i, d, j)
                        best_mdl = tmp_mdl
                except: continue
    print('aic: {:6.5f} | order: {}'.format(best_aic, best_order))                    
    return best_aic, best_order, best_mdl

# %%
aic, order, mdl = _get_best_model(series)
# Out:
# aic: 858.17298 | order: (3, 1, 2)

# %%
tsplot(mdl.resid)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -2.024906
# p-value                         0.275760
# #Lags Used                     11.000000
# Number of Observations Used    64.000000
# Critical Value (1%)            -3.536928
# Critical Value (5%)            -2.907887
# Critical Value (10%)           -2.591493
# dtype: float64

# %%
series = series[1:] - series[:-1]

# %%
series = series[12:] - series[:-12]

# %%
series = series[10:] - series[:-10]

# %%
series = series.astype(float)

# %%
tsplot(series)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -3.883404
# p-value                         0.002160
# #Lags Used                      9.000000
# Number of Observations Used    44.000000
# Critical Value (1%)            -3.588573
# Critical Value (5%)            -2.929886
# Critical Value (10%)           -2.603185
# dtype: float64

# %%
p_ = 3
o_ = 1
q_ = 2

am = arch_model(series, p=p_, o=o_, q=q_, dist='StudentsT')
res = am.fit(update_freq=5, disp='off')
print(res.summary())
# Out:
#                       Constant Mean - GJR-GARCH Model Results
# ====================================================================================
# Dep. Variable:                            y   R-squared:                       0.000
# Mean Model:                   Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                        GJR-GARCH   Log-Likelihood:               -316.274
# Distribution:      Standardized Student's t   AIC:                           650.548
# Method:                  Maximum Likelihood   BIC:                           668.448
#                                               No. Observations:                   54
# Date:                      Thu, Aug 11 2022   Df Residuals:                       53
# Time:                              20:51:44   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu           -12.1933     35.016     -0.348      0.728 [-80.823, 56.436]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega        846.6178   6976.240      0.121      0.903 [-1.283e+04,1.452e+04]
# alpha[1]   1.8179e-16      0.646  2.816e-16      1.000      [ -1.265,  1.265]
# alpha[2]       0.0155      0.682  2.270e-02      0.982      [ -1.321,  1.352]
# alpha[3]   7.0973e-13      0.391  1.814e-12      1.000      [ -0.767,  0.767]
# gamma[1]       0.5148      1.801      0.286      0.775      [ -3.016,  4.046]
# beta[1]        0.3775      2.004      0.188      0.851      [ -3.550,  4.304]
# beta[2]        0.3497      1.845      0.190      0.850      [ -3.266,  3.965]
#                                  Distribution
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# nu           225.0859   1817.468      0.124      0.901 [-3.337e+03,3.787e+03]
# =============================================================================
#
# Covariance estimator: robust

# %%
tsplot(res.resid)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -3.883404
# p-value                         0.002160
# #Lags Used                      9.000000
# Number of Observations Used    44.000000
# Critical Value (1%)            -3.588573
# Critical Value (5%)            -2.929886
# Critical Value (10%)           -2.603185
# dtype: float64
